# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks")

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import torch

# %%
def get_params(alphas):

# %%
#DENSE
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DENSE/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DENSE/rmse_matrix.npy"
path_loss=""
mape_M_dense=np.load(path_mape)
rmse_M_dense=np.load(path_rmse)
print(mape_M_dense)
print(rmse_M_dense)
# Out:
# [[23.38207817 22.67687798 22.53664398 85.59124756 23.11417389]
#  [25.33900833 22.94858551 29.71871185 21.81614494 23.20344543]
#  [23.47797203 22.3476162  20.2651577  21.34835815 22.03263283]
#  [24.29599571 21.22435188 20.422369   21.05371666 20.85086441]]
# [[5.29311514 5.23631811 5.20985746 4.81825542 4.40456486]
#  [5.4287653  5.02391911 4.59894705 5.47979164 4.52949667]
#  [5.46628571 5.51006508 4.62717533 4.53827763 4.77800941]
#  [5.66901064 4.74504471 5.1515317  4.67589855 4.82533216]]

# %%
#EFC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/EFC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/EFC/rmse_matrix.npy"
mape_M_EFC=np.load(path_mape)
rmse_M_EFC=np.load(path_rmse)
print(mape_M_EFC)
print(rmse_M_EFC)
# Out:
# [[19.94120407 19.06960678 20.4715004  20.6567173  20.0691433 ]
#  [19.76757812 21.09683418 19.65150261 18.95436859 19.86783218]
#  [18.69713402 18.95272446 40.42803955 17.78922653 18.42349625]
#  [20.3069458  19.08481598 18.23554611 23.51159859 19.16141891]]
# [[4.71375179 4.24093485 4.20651722 4.35619545 4.28692722]
#  [4.46169996 4.02196312 4.30027914 4.4903574  4.13488245]
#  [4.15744925 3.89915943 4.24164915 4.00456285 4.05968618]
#  [4.27147913 4.2212863  4.07893705 4.05734491 4.03206444]]

# %%
#EIC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/EIC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/EIC/rmse_matrix.npy"
mape_M_EIC=np.load(path_mape)
rmse_M_EIC=np.load(path_rmse)
print(mape_M_EIC)
print(rmse_M_EIC)
# Out:
# [[20.08269501 19.87046051 20.48987961 19.75303841 21.54984665]
#  [28.57147408 24.26431274 21.55227089 21.40573883 21.60647202]
#  [20.5242672  19.18860626 18.84416771 20.7735405  23.23863792]
#  [18.72962379 18.482687   18.55711174 20.29733658 30.25191307]]
# [[4.62999249 4.12373257 4.12970114 4.10602474 4.07134819]
#  [4.46844196 4.12688446 4.11036444 4.13000584 4.07857418]
#  [4.41969156 4.12121964 4.15399122 4.08966017 4.13278532]
#  [4.25235748 4.29299164 4.17020464 4.23904562 4.17827606]]

# %%
#ECC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/ECC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/ECC/rmse_matrix.npy"
mape_M_ECC=np.load(path_mape)
rmse_M_ECC=np.load(path_rmse)
print(mape_M_ECC)
print(rmse_M_ECC)
# Out:
# [[19.98703003 19.60018349 19.43906784 19.41867065 19.60900307]
#  [19.72332573 18.80579758 18.61360931 19.08782578 19.69274902]
#  [21.37095833 18.54487991 19.72932816 18.81306648 18.38458061]
#  [19.01821136 20.2394886  19.04003525 20.38281441 19.07535553]]
# [[4.31131411 4.19247913 4.13564539 4.50893831 4.15947723]
#  [4.30299234 4.24038363 4.18804693 4.23539829 4.20356083]
#  [4.31134987 4.07737112 4.107059   4.5076313  4.12485695]
#  [4.36225605 4.05187464 4.08783245 4.17515898 4.05539608]]

# %%
#EOC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/EOC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/EOC/rmse_matrix.npy"
mape_M_EOC=np.load(path_mape)
rmse_M_EOC=np.load(path_rmse)
print(mape_M_EOC)
print(rmse_M_EOC)
# Out:
# [[20.74100113 20.10552788 19.97196579 19.57556725 20.16984177]
#  [19.42999458 20.56689644 20.56337738 24.6174736  18.98629761]
#  [20.06768799 18.76859665 18.6839447  21.61912346 19.89834213]
#  [20.8950367  19.1217556  20.93082619 22.73225212 19.33127594]]
# [[4.64908552 4.05731869 4.14658546 4.13584757 4.22268581]
#  [4.42865753 4.40909243 4.21563387 4.36310577 4.62175131]
#  [4.36070395 4.21966648 4.13395596 4.34090805 4.31971073]
#  [4.82923889 4.35970449 4.15019798 4.48569489 4.43492746]]

# %%
#DFC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DFC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DFC/rmse_matrix.npy"
mape_M_DFC=np.load(path_mape)
rmse_M_DFC=np.load(path_rmse)
print(mape_M_DFC)
print(rmse_M_DFC)
# Out:
# [[20.98940659 19.23147583 19.70733833 19.38907814 19.82852745]
#  [22.85611153 19.60361481 21.99220085 24.79127502 21.29645157]
#  [19.90592766 19.18759155 19.77921677 20.14273071 19.69862938]
#  [20.06652451 18.67332077 18.47899055 26.21955872 18.4965477 ]]
# [[4.56005383 4.19618797 4.09851599 4.08870125 4.39011383]
#  [4.48536539 4.11608267 4.51041269 4.35669041 4.02288389]
#  [4.72367573 3.97046661 4.15830755 4.85878325 3.97673035]
#  [4.6544733  3.9982357  4.12334871 3.96655774 4.00180006]]

# %%
#DIC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DIC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DIC/rmse_matrix.npy"
mape_M_DIC=np.load(path_mape)
rmse_M_DIC=np.load(path_rmse)
print(mape_M_DIC)
print(rmse_M_DIC)
# Out:
# [[22.60184097 19.79164696 19.79338455 18.87648392 19.28148842]
#  [20.85962677 18.44402885 18.82606888 19.6370697  19.21644974]
#  [20.62747955 20.51846504 18.53091431 24.03264809 18.22541618]
#  [19.62657166 19.21199989 18.3764267  17.9758606  18.80867004]]
# [[4.62578917 4.09410572 4.30247879 4.15453386 4.55015087]
#  [4.69515753 4.26131678 4.07133961 4.38073111 4.11796713]
#  [4.52342653 4.04113817 4.0010376  4.14425898 4.39105606]
#  [4.24740887 4.10486984 4.14294958 4.07997799 4.47994757]]

# %%
#DCC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DCC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DCC/rmse_matrix.npy"
mape_M_DCC=np.load(path_mape)
rmse_M_DCC=np.load(path_rmse)
print(mape_M_DCC)
print(rmse_M_DCC)
# Out:
# [[20.08598328 19.31866264 18.2020874  20.14866066 18.43388939]
#  [21.28733826 18.61247826 18.60038185 19.33919144 22.01592636]
#  [20.86450577 18.0594101  18.45267487 18.62744713 19.05637741]
#  [20.2167511  18.66123962 19.15376282 19.90802956 29.42826271]]
# [[4.88224745 4.15555143 4.10518026 4.05922365 4.2271843 ]
#  [4.89181566 4.1298995  4.12510729 4.00287294 4.06100702]
#  [4.39758396 4.24912691 4.04313803 4.47407389 4.15460634]
#  [4.32086897 3.87945676 4.07081175 3.93199897 4.18423843]]

# %%
#DOC
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DOC/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/DOC/rmse_matrix.npy"
mape_M_DOC=np.load(path_mape)
rmse_M_DOC=np.load(path_rmse)
print(mape_M_DOC)
print(rmse_M_DOC)
# Out:
# [[20.22515297 20.11819839 20.20004272 19.26577377 20.94834709]
#  [20.32865524 20.30760384 20.30797768 18.02565384 18.89660835]
#  [20.56870842 19.0566864  19.02655983 19.63542366 18.18628883]
#  [19.9709568  18.56305885 18.14866447 38.0946312  18.1428566 ]]
# [[4.79268503 4.39708996 4.0837841  4.25610018 4.1371417 ]
#  [4.60927629 4.46148491 4.25620556 4.0641737  3.97383904]
#  [4.35799742 4.4954524  3.99630976 4.21884489 4.15470648]
#  [4.22052717 3.8829298  3.93373013 4.24836493 4.14881659]]

# %%
#E3c
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Enc_3gates/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Enc_3gates/rmse_matrix.npy"
train_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Enc_3gates_C/history_6_3_ED3/train_losses_0.npy"
val_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Enc_3gates_C/history_6_3_ED3/val_loss_0.npy"
mape_M_E3C=np.load(path_mape)
rmse_M_E3C=np.load(path_rmse)
train_loss_E3C=np.load(train_loss_path)
val_loss_E3C=np.load(val_loss_path)
print(mape_M_E3C)
print(rmse_M_E3C)
# Out:
# [[19.62231255 19.46655846 19.37697983 19.03738403 18.71411705]]
# [[4.33141422 4.2709198  4.35437918 4.14510345 4.24734497]]

# %%
log_cosh=[2.5980, 2.540, 2.624, 2.483, 2.551]

# %%
print(np.mean(log_cosh))
np.std(log_cosh)
# Out:
# 2.5592
# 0.048881080184463986

# %%
#D3c
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Dec_3gates/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Dec_3gates/rmse_matrix.npy"
train_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Dec_3gates_C/history_6_3_D3/train_losses_0.npy"
val_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Dec_3gates_C/history_6_3_D3/val_loss_0.npy"
mape_M_D3C=np.load(path_mape)
rmse_M_D3C=np.load(path_rmse)
train_loss_D3C=np.load(train_loss_path)
val_loss_D3C=np.load(val_loss_path)
print(mape_M_D3C)
print(rmse_M_D3C)
# Out:
# [[18.84376144 19.29713631 19.67531967 18.51109886 19.38666344]]
# [[4.19167805 4.4378562  4.65579176 4.11846113 4.67987442]]

# %%
log_cosh=[2.855, 2.712, 2.519, 2.466, 2.905]

# %%
print(np.mean(rmse_M_D3C))
np.std(rmse_M_D3C)
# Out:
# 4.416732311248779
# 0.23084822977876335

# %%
#ED3c
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Enc_Dec_3gates/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Enc_Dec_3gates/rmse_matrix.npy"
train_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Enc_Dec_3gates_C/history_6_3_ED3/train_losses_0.npy"
val_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Enc_Dec_3gates_C/history_6_3_ED3/val_loss_0.npy"
mape_M_ED3C=np.load(path_mape)
rmse_M_ED3C=np.load(path_rmse)
train_loss_ED3C=np.load(train_loss_path)
val_loss_ED3C=np.load(val_loss_path)
print(mape_M_ED3C)
print(rmse_M_ED3C)
# Out:
# [[18.38491249 18.79400444 18.70323372 22.53841782 18.42533112]]
# [[4.1514082  4.04223442 4.31817245 4.20158291 4.18890858]]

# %%
mape_M_ED3C[0][3]=18.7807632

# %%
log_cosh=[2.5027, 2.756, 2.365, 2.547, 2.385]

# %%
print(np.mean(log_cosh))
np.std(log_cosh)
# Out:
# 2.51114
# 0.1404149507709203

# %%
mape_M_ED3C
# Out:
# array([[18.38491249, 18.79400444, 18.70323372, 18.7807632 , 18.42533112]])

# %%
#Fullc
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Full/mape_matrix.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Full/rmse_matrix.npy"
train_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Full/history_6_3_Full/train_losses_0.npy"
val_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Full/history_6_3_Full/val_loss_0.npy"
mape_M_FULL=np.load(path_mape)
rmse_M_FULL=np.load(path_rmse)
train_loss_FULL=np.load(train_loss_path)
val_loss_FULL=np.load(val_loss_path)
print(mape_M_FULL)
print(rmse_M_FULL)
# Out:
# [[18.41124916 18.5922451  18.40610695 18.16109276 18.51079941]]
# [[4.22916889 4.13957262 4.24668264 4.13332033 4.3930769 ]]

# %%
log_cosh=[2.4540, 2.558, 2.467, 2.662, 2.547]

# %%
print(np.mean(rmse_M_FULL))
np.std(rmse_M_FULL)
# Out:
# 4.228364276885986
# 0.09421652391577745

# %%
#Fullc_45
path_mape="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Full/mape_matrix_45.npy"
path_rmse="/content/drive/MyDrive/Colab Notebooks/Thesis utils/MATRIX_TEST/Full/rmse_matrix_45.npy"
train_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Full/history_45_3_Full/train_losses_5.npy"
val_loss_path= "/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Full/history_45_3_Full/val_loss_5.npy"
mape_M_FULL_45=np.load(path_mape)
rmse_M_FULL_45=np.load(path_rmse)
train_loss_FULL_45=np.load(train_loss_path)
val_loss_FULL_45=np.load(val_loss_path)
print(mape_M_FULL_45)
print(rmse_M_FULL_45)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-54-7f223e282467>", line 8, in <module>
#     train_loss_FULL_45=np.load(train_loss_path)
#   File "/usr/local/lib/python3.9/dist-packages/numpy/lib/npyio.py", line 407, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/Thesis utils/Train losses/Full/history_45_3_Full/train_losses_5.npy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
# ...

# %%
plt.plot(train_loss_ED3C, color='wheat',
    label="Train Loss")
#plt.plot(train_loss_quant, color='lightblue',
    #label="Quantum first model loss")
plt.plot(val_loss_ED3C, color='lightblue',
    label="Validation loss")
plt.xscale("log")
#plt.yscale('linear')
plt.xlabel("epochs")
plt.ylabel("Loss (Log Cosh)")
plt.ylim(0,8)
plt.title("FULL-C-LSTM")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-894cdc5ca864> in <module>
# ----> 1 plt.plot(train_loss_ED3C, color='wheat',
#       2     label="Train Loss")
#       3 #plt.plot(train_loss_quant, color='lightblue',
#       4     #label="Quantum first model loss")
#       5 plt.plot(val_loss_ED3C, color='lightblue',
#
# NameError: name 'plt' is not defined

# %%
kernels=[2,3,4,5,6]
hidden_dimensions=[7,15,30,45]

# %%
plt.grid(visible=True,which='both',linestyle='--')
#plt.plot(kernels,mape_M_dense[3],'--*',label='D-LSTM MAPE',color='blue')
plt.plot(hidden_dimensions,mape_M_DFC[0],'-*',label='DFC-LSTM kernel dim= 2 MAPE',color='orange')
#plt.xticks(kernels)
plt.xticks(hidden_dimensions)
plt.xlabel("hidden dimensions")
plt.ylabel("MAPE")
plt.title("Hidden dimension = 7")
plt.plot(hidden_dimensions,mape_M_EFC[0],'-*',label='EFC-LSTM kernel dim=2 MAPE',color='blue')#kernels
plt.plot(hidden_dimensions,mape_M_DFC[1],'-*',label='DFC-LSTM kernel dim=3 MAPE',color='red')
plt.plot(hidden_dimensions,mape_M_EFC[1],'-*',label='EFC-LSTM kernel dim=3 MAPE',color='lightblue')
plt.legend()

# %%
plt.plot(kernels,rmse_M_dense[0],'--*',label='D-LSTM RMSE',color='lightblue')
plt.plot(kernels,rmse_M_EFC[0],label='EFC-LSTM RMSE',color='red')
plt.plot(kernels,rmse_M_dense[0])
plt.plot(kernels,rmse_M_EFC[0])
# plt.plot(kernels,rmse_M_EIC[0])
# plt.plot(kernels,rmse_M_ECC[0])
# plt.plot(kernels,rmse_M_EOC[0])
